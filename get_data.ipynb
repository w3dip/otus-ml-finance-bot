# %%
# !pip install ccxt -q

from utils.config import COMMON_CONFIG
from utils.api import get_data_from_api
from utils.files import save_data_to_file

# %%
df = get_data_from_api(COMMON_CONFIG.SYMBOL, COMMON_CONFIG.TIMEFRAME, COMMON_CONFIG.START_DATE)
save_data_to_file(df, COMMON_CONFIG.DATA_PATH, COMMON_CONFIG.SYMBOL, COMMON_CONFIG.TIMEFRAME)
df
# Out:
# Fetched 500 ETH/USDT 1h candles from 2023-01-01T00:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-01-21T20:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-02-11T16:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-03-04T12:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-03-25T09:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-04-15T05:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-05-06T01:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-05-26T21:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-06-16T17:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-07-07T13:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-07-28T09:00:00.000Z
# Sleep for 0.05
# Fetched 500 ETH/USDT 1h candles from 2023-08-18T05:00:00.000Z
# Sleep for 0.05
# ...
